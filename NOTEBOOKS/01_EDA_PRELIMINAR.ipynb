# %% [markdown]
# ## Instalo librerias

# %%
import pandas as pd

from pathlib import Path

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\propietario\desktop\proyecto_final\proyecto_final_data_analytics\entorno_proyecto_final\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
clientes_path = Path(r"C:\Users\Propietario\Desktop\PROYECTO_FINAL\Proyecto_final_Data_Analytics\DATA\DATA_RAW\clientes_sinteticos.csv")
trans_path    = Path(r"C:\Users\Propietario\Desktop\PROYECTO_FINAL\Proyecto_final_Data_Analytics\DATA\DATA_RAW\transacciones_sinteticas.csv")

import pandas as pd
df_clientes = pd.read_csv(clientes_path)
df_trans    = pd.read_csv(trans_path)
